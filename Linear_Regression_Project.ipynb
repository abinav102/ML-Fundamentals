# %% [markdown]
# <a href="https://colab.research.google.com/github/abinav102/ML-Fundamentals/blob/main/Linear_Regression_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([1,2,4,5,7,8,9])
y = np.array([10,25,35,55,60,78,85])

X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
m = model.coef_
c = model.intercept_
print(m)
print(c)
prediction = model.predict(X_test)
# Out:
# [[8.87634409]]
# [4.7688172]

# %%
plt.scatter(X,y,color='red',label='Data Points')
plt.plot(X,model.predict(X),color='blue',label = 'Best Fit Line')
plt.xlabel('Hours Studied')
plt.ylabel('Marks Scored')
plt.title('Linear Regression Model')
plt.show()
