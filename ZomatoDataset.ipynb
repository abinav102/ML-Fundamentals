# %% [markdown]
# <a href="https://colab.research.google.com/github/abinav102/ML-Fundamentals/blob/main/ZomatoDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
zomato = pd.read_csv('zomato.csv',encoding = 'latin-1')
zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
zomato.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# 9 missing values for cuisine , which has a datatype of 'object'----> could be string values

# %% [markdown]
# Dropping the missing rows using .dropna() function

# %%
zomato.dropna(subset=['Cuisines'],inplace = True)  #subset=['Cuisines']-->look for nulls only in that column
zomato.info()                                                 #inplace = True--> modify the dataframe directly
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %% [markdown]
# Changing Yes/No values into binary

# %%
category = ['Has Table booking','Has Online delivery','Is delivering now','Switch to order menu']
for cols in category:
    zomato[cols] = zomato[cols].map({'Yes':1,'No':0})
zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# PRINTING THE TOP 5 RESTAURANTS BASED ON **RATING**

# %%
grouped_by_locality = zomato.groupby('Locality')
avg_rating = grouped_by_locality['Aggregate rating'].mean()
top_5 = avg_rating.sort_values(ascending = False)
top_5.head()
# Out:
# Locality
# West Park                                      4.9
# Aminabad                                       4.9
# Venetian Village, Al Maqtaa                    4.9
# Sofitel Philippine Plaza Manila, Pasay City    4.9
# Setor De Clubes Esportivos Sul                 4.9
# Name: Aggregate rating, dtype: float64

# %%
restaurant_count = zomato.groupby('Locality').size()
locality_stats = pd.DataFrame({'Average Rating ' : avg_rating , 'Restaurant count': restaurant_count})
locality_stats.head()
# Out:
#                                      Average Rating   Restaurant count
# Locality
#  ILD Trade Centre Mall, Sohna Road              3.05                 2
# 12th Square Building, Banjara Hills             4.30                 1
# A Hotel, Gurdev Nagar                           3.60                 1
# ARSS Mall, Paschim Vihar                        3.10                 1
# Aaya Nagar                                      0.00                 1

# %%
reliable_localities = locality_stats[locality_stats['Restaurant count']>30]
top_10 = reliable_localities.sort_values(by = 'Average Rating ',ascending = False)
top_10.head()
# Out:
#                                       Average Rating   Restaurant count
# Locality
# Cyber Hub, DLF Cyber City                    3.860976                41
# DLF Mall of India, Sector 18,  Noida         3.841935                31
# Khan Market                                  3.715909                44
# Greater Kailash (GK) 1                       3.696970                66
# Connaught Place                              3.686885               122

# %%
zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# value_counts()---> how many times each unique value appears in a column

# %%
zomato['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %% [markdown]
# # **PLOTTING** **A** **GRAPH**

# %%
rating_counts = zomato['Rating text'].value_counts()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,6))  #set the figure size---> 10 inches wide,6 inches tall
sns.barplot(x = rating_counts.index, y = rating_counts.values)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Dealing with the 'not rated' restaurants

# %%
not_rated = zomato[zomato['Rating text']=='Not rated']
not_rated['Votes'].describe()
# Out:
# count    2148.000000
# mean        0.870112
# std         1.048600
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         3.000000
# Name: Votes, dtype: float64

# %%
top_cuisines = zomato['Cuisines'].value_counts()
top_cuisines.head()
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64
